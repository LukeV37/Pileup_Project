# %%
import uproot
import numpy as np
import awkward as ak
import random
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
with uproot.open("ntuples/dataset_mu60_ztt1000_10k.root:fastjet") as f:
    jet_pt_sig = f["jet_pt"].array()
    jet_eta_sig = f["jet_eta"].array()
    jet_phi_sig = f["jet_phi"].array()
    jet_m_sig = f["jet_m"].array()
    jet_pufr_sig = f["jet_pufr_truth"].array()
    jet_idx_sig = f["jet_ttbar_match"].array()
    jet_label_sig = ak.ones_like(jet_pt_sig)

with uproot.open("ntuples/dataset_mu60_ttbar_10k.root:fastjet") as f:
    jet_pt_bkg = f["jet_pt"].array()
    jet_eta_bkg = f["jet_eta"].array()
    jet_phi_bkg = f["jet_phi"].array()
    jet_m_bkg = f["jet_m"].array()
    jet_pufr_bkg = f["jet_pufr_truth"].array()
    jet_idx_bkg = f["jet_ttbar_match"].array()
    jet_label_bkg = ak.zeros_like(jet_pt_bkg)

# %%
print(jet_pt_sig[0])
print(jet_eta_sig[0])
# Out:
# [228, 172, 117, 98.6, 84.6, 47.1, 38.5, ..., 27.3, 26.7, 26.4, 25.8, 25.8, 25.5]
# [-1.18, 1.31, 0.943, -1.1, 0.682, 1.56, ..., -2.4, 3.03, -3.3, 1.94, 1.83]

# %%
# crazy vectorized syntax https://awkward-array.org/doc/main/user-guide/how-to-restructure-concatenate.html#emulating-numpy-s-stack-functions
jet_sig = ak.concatenate([jet_pt_sig[:, np.newaxis], jet_eta_sig[:, np.newaxis], jet_phi_sig[:, np.newaxis], jet_pufr_sig[:, np.newaxis], jet_label_sig[:, np.newaxis]], axis=1)
jet_bkg = ak.concatenate([jet_pt_bkg[:, np.newaxis], jet_eta_bkg[:, np.newaxis], jet_phi_bkg[:, np.newaxis], jet_pufr_bkg[:, np.newaxis], jet_label_bkg[:, np.newaxis]], axis=1)

jet_feats = ak.concatenate([jet_sig, jet_bkg], axis=0)
jet_labels = ak.concatenate([jet_label_sig, jet_label_bkg], axis=0)
jet_idx = ak.concatenate([jet_idx_sig, jet_idx_bkg], axis=0)

# %%
print(jet_sig[0][0])
print(jet_sig[0][1])
print()
print(jet_sig[0,:,0])
# Out:
# [228, 172, 117, 98.6, 84.6, 47.1, 38.5, ..., 27.3, 26.7, 26.4, 25.8, 25.8, 25.5]
# [-1.18, 1.31, 0.943, -1.1, 0.682, 1.56, ..., -2.4, 3.03, -3.3, 1.94, 1.83]
#
# [228, -1.18, 2.05, 0.0379, 1]

# %%
# %%time
num_events = len(jet_pt_sig)
jet_list = []
for event in range(num_events):
    if (len(np.unique(jet_idx[event])) != 6):
        continue
    idx = jet_idx[event]
    jet_list_tmp = []
    for i, jet in enumerate(idx):
        jet_list_tmp.append(np.array(jet_feats[event,:,jet]))
    jet_list.append(np.array(jet_list_tmp))
# Out:
# CPU times: user 4.55 s, sys: 26.2 ms, total: 4.58 s
# Wall time: 4.55 s

# %%
random.shuffle(jet_list)
data = np.array(jet_list)
print(data.shape)
# Out:
# (3651, 6, 5)

# %%
num_events = len(data)
X_train = torch.Tensor(data[0:int(0.7*num_events)][:,:,0:4])
y_train = torch.Tensor(data[0:int(0.7*num_events)][:,:,4].mean(axis=1).reshape(-1,1))
X_val = torch.Tensor(data[int(0.7*num_events):int(0.75*num_events)][:,:,0:4])
y_val = torch.Tensor(data[int(0.7*num_events):int(0.75*num_events)][:,:,4].mean(axis=1).reshape(-1,1))
X_test = torch.Tensor(data[int(0.75*num_events):][:,:,0:4])
y_test = torch.Tensor(data[int(0.75*num_events):][:,:,4].mean(axis=1).reshape(-1,1))

# %%
class Model(nn.Module):
    def __init__(self, in_feats, hidden_feats, out_feats):
        super(Model, self).__init__()        
        self.jet_preprocess = nn.Linear(in_feats,hidden_feats)
        self.jet_postprocess = nn.Linear(hidden_feats,out_feats)
    def forward(self, jet_feats):
        jet_embedding = F.relu(self.jet_preprocess(jet_feats))
        jet_aggregated = jet_embedding.sum(dim=1)
        output = F.sigmoid(self.jet_postprocess(jet_aggregated))
        return output

# %%
def train(model, data, epochs=20):
    X_train, y_train, X_val, y_val = data
    
    history = {'train_loss':[],'test_loss':[]}

    for e in range(epochs):
        optimizer.zero_grad()
        outputs = model(X_train.to(device))
        loss = loss_fn(outputs, y_train.to(device))
        loss.backward()
        optimizer.step()

        model.eval()
        history['train_loss'].append(loss.detach().cpu().numpy())
        y_pred = model(X_val.to(device))
        test_loss = loss_fn(y_pred,y_val.to(device)).detach().cpu().numpy()
        history['test_loss'].append(test_loss)
        if (e+1)%100==0:
            print('Epoch:',e+1,'\tTrain Loss:',round(float(loss),8),'\tTest Loss:',round(float(test_loss),8))

    return history

# %%
print("GPU Available: ", torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# GPU Available:  False
# cpu

# %%
loss_fn = nn.BCELoss()

baseline = Model(3,128,1).to(device)
optimizer = optim.Adam(baseline.parameters(), lr=0.000005)
data = [X_train[:,:,0:3], y_train, X_val[:,:,0:3], y_val]
baseline_history = train(baseline, data, epochs=1000)

model = Model(4,128,1).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.000005)
data = [X_train, y_train, X_val, y_val]
model_history = train(model, data, epochs=1000)

plt.plot(baseline_history['train_loss'],label='train')
plt.plot(baseline_history['test_loss'],label='test')
plt.title("Loss")
plt.legend()
plt.show()

plt.plot(model_history['train_loss'],label='train')
plt.plot(model_history['test_loss'],label='test')
plt.title("Loss")
plt.legend()
plt.show()
# Out:
# Epoch: 100 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 200 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 300 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 400 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 500 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 600 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 700 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 800 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 900 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 1000 	Train Loss: 0.0 	Test Loss: 0.0
# Epoch: 100 	Train Loss: 68.71142578 	Test Loss: 67.49662018
# Epoch: 200 	Train Loss: 56.6806488 	Test Loss: 55.81499863
# Epoch: 300 	Train Loss: 39.1472435 	Test Loss: 38.35271835
# Epoch: 400 	Train Loss: 20.82862282 	Test Loss: 20.35869598
# Epoch: 500 	Train Loss: 5.44680023 	Test Loss: 5.3285284
# Epoch: 600 	Train Loss: 0.23580803 	Test Loss: 0.25974229
# Epoch: 700 	Train Loss: 0.10367347 	Test Loss: 0.11732331
# Epoch: 800 	Train Loss: 0.06641588 	Test Loss: 0.07599594
# Epoch: 900 	Train Loss: 0.04826255 	Test Loss: 0.0556318
# Epoch: 1000 	Train Loss: 0.03745157 	Test Loss: 0.04341301

# %%
from sklearn.metrics import roc_curve, roc_auc_score
model.to('cpu')
y_pred = model(X_test).detach()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
print(min(y_test))
plt.plot(fpr,tpr)
plt.plot([[0,0],[1,1]],'--',color='k')
plt.title("ROC Curve")
plt.show()
print("ROC AUC: ", round(roc_auc_score(y_test, y_pred),4))
# Out:
# tensor([1.])
# /home/lvaughan/VirtualEnvs/torch/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1174: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 10
#       8 plt.title("ROC Curve")
#       9 plt.show()
# ---> 10 print("ROC AUC: ", round(roc_auc_score(y_test, y_pred),4))
#
# File ~/VirtualEnvs/torch/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/VirtualEnvs/torch/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:640, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     638     labels = np.unique(y_true)
#     639     y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 640     return _average_binary_score(
#     641         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     642         y_true,
#     643         y_score,
#     644         average,
#     645         sample_weight=sample_weight,
#     646     )
#     647 else:  # multilabel-indicator
#     648     return _average_binary_score(
#     649         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     650         y_true,
#    (...)
#     653         sample_weight=sample_weight,
#     654     )
#
# File ~/VirtualEnvs/torch/lib/python3.10/site-packages/sklearn/metrics/_base.py:76, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      73     raise ValueError("{0} format is not supported".format(y_type))
#      75 if y_type == "binary":
# ---> 76     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78 check_consistent_length(y_true, y_score, sample_weight)
#      79 y_true = check_array(y_true)
#
# File ~/VirtualEnvs/torch/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:382, in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     380 """Binary roc auc score."""
#     381 if len(np.unique(y_true)) != 2:
# --> 382     raise ValueError(
#     383         "Only one class present in y_true. ROC AUC score "
#     384         "is not defined in that case."
#     385     )
#     387 fpr, tpr, _ = roc_curve(y_true, y_score, sample_weight=sample_weight)
#     388 if max_fpr is None or max_fpr == 1:
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
